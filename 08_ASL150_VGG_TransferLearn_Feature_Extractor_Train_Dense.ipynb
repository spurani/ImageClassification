# %% [markdown]
# <h1 style="font-size:30px;">Transfer Learning using VGG-16 (as a Feature Extractor)</h1>
#
# In this notebook, we are going to demonstrate another example of **transfer learning** using a different dataset: **American Sign Language (ASL)**. As before, we will instantiate the convolutional base of the VGG-16 network architecture using pre-trained weights from the ImageNet dataset. Then we will add our own dense classifier and only train that portion of the network on the **ASL** dataset. Since the ASL dataset contains types of images (hand signals) that are not part of the ImageNet dataset, we expect the transfer learning to be less effective than for the **Type of Balls** dataset, in the previous notebook.
#
# <img src='https://opencv.org/wp-content/uploads/2022/03/c4_03_cnn_vgg_pretrained_base_ASL.png' width=1000 align='center'><br/>

# %% [markdown]
# ## Table of Contents
# * [1 System Configuration](#1-System-Configuration)
# * [2 Download and Extract the Dataset](#2-Download-and-Extract-the-Dataset)
# * [3 Dataset and Training Configuration](#3-Dataset-and-Training-Configuration)
# * [4 Modeling VGG-16](#4-Modeling-VGG-16)
# * [5 Model Evaluation](#5-Model-Evaluation)
# * [6 Conclusion](#6-Conclusion)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import random
import numpy as np
import os
import matplotlib.pyplot as plt
import cv2
import zipfile
import requests
import glob as glob

from tensorflow.keras.utils import image_dataset_from_directory

from matplotlib.ticker import (MultipleLocator, FormatStrFormatter)
from dataclasses import dataclass 

block_plot = False
plt.rcParams['figure.figsize'] = (12, 9) 
SEED_VALUE = 42

# %% [markdown]
# ## 1 System Configuration

# %%
def system_config():
    
    # Get list of GPUs.
    gpu_devices = tf.config.list_physical_devices('GPU')
    print(gpu_devices)
    
    if len(gpu_devices) > 0:
        print('Using GPU')
        os.environ["CUDA_VISIBLE_DEVICES"] = '0'
        os.environ['TF_CUDNN_DETERMINISTIC'] = '1' 
        
        # If there are any gpu devices, use first gpu.
        tf.config.experimental.set_visible_devices(gpu_devices[0], 'GPU')
        
        # Grow the memory usage as it is needed by the process.
        tf.config.experimental.set_memory_growth(gpu_devices[0], True)
        
        # Enable using cudNN.
        os.environ['TF_USE_CUDNN'] = "true"
    else:
        print('Using CPU')

system_config()
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Using GPU

# %% [markdown]
# ## 2 Download and Extract the Dataset

# %%
def download_file(url, save_name):
    url = url
    file = requests.get(url)

    open(save_name, 'wb').write(file.content)

# %%
def unzip(zip_file=None):
    try:
        with zipfile.ZipFile(zip_file) as z:
            z.extractall("./")
            print("Extracted all")
    except:
        print("Invalid file")

# %%
download_file(
    'https://www.dropbox.com/s/7huaqeavdbz32la/dataset_ASL_150.zip?dl=1',
    'dataset_ASL_150.zip'
)
    
unzip(zip_file='dataset_ASL_150.zip')
# Out:
# Extracted all

# %% [markdown]
# ## 3 Dataset and Training Configuration

# %%
@dataclass(frozen=True)
class DatasetConfig:
    NUM_CLASSES: int = 29
    IMG_HEIGHT:  int = 224
    IMG_WIDTH:   int = 224
    CHANNELS:    int = 3
    BATCH_SIZE:  int = 32
    DATA_ROOT:   str = './dataset_ASL_150'
        
@dataclass(frozen=True)
class TrainingConfig:
    BATCH_SIZE:     int   = 32
    EPOCHS:         int   = 51
    LEARNING_RATE:  float = 0.0001
    CHECKPOINT_DIR: str   = './saved_models_asl'

# %% [markdown]
# ## 4 Modeling VGG-16
#
# The Keras API provides the following utility that is used to instantiate a VGG-16 model which can be initialized with either pre-trained weights from ImageNet or random initial weights. **In this notebook, we will load the model with weights from the ImageNet dataset.** For more information refer to the: <a href="https://www.tensorflow.org/api_docs/python/tf/keras/applications/vgg16/VGG16" target="_blank">Keras VGG-16 Model API</a>
#
# ```python
# tf.keras.applications.vgg16.VGG16(include_top=True,
#                                   weights='imagenet',
#                                   input_tensor=None,
#                                   input_shape=None,
#                                   pooling=None,
#                                   classes=1000,
#                                   classifier_activation='softmax',
#                                  )
# ```
# ### 4.1 VGG Convolutional Base
#
# We begin by creating a model of the VGG-16 convolutional base. We can do this by instantiating the model and setting `include_top = False` which excludes the fully connected layers. **In the previous notebook, we will instantiate the model with weights from the ImageNet dataset.**

# %%
input_shape = (DatasetConfig.IMG_HEIGHT, DatasetConfig.IMG_WIDTH, DatasetConfig.CHANNELS)

print('Loading model with ImageNet weights...')
vgg16_conv_base = tf.keras.applications.vgg16.VGG16(input_shape=input_shape,
                                                    include_top=False, # We will supply our own top.
                                                    weights='imagenet',
                                                   )
# Set the `trainable` attribute of the convolutional base to `False` so that the weights are not changed. 
vgg16_conv_base.trainable = False
print('All weights trainable, fine tuning...')
# Out:
# Loading model with ImageNet weights...
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 1s 0us/step
# 58900480/58889256 [==============================] - 1s 0us/step
# All weights trainable, fine tuning...

# %%
print(vgg16_conv_base.summary())
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 0
# Non-trainable params: 14,714,688
# _________________________________________________________________
# None

# %% [markdown]
# ### 4.2 Add the Classification Layer
# Since we intend to train and use the model to classify hand signals from the ASL dataset (which has 29 classes), we will need to add our own classification layer. **This is the same approach we used in the previous notebook with the exception that we are using a wider fully connected layer below (512 vs 256).**

# %%
inputs = tf.keras.Input(shape=input_shape)
    
x = tf.keras.applications.vgg16.preprocess_input(inputs)
    
x = vgg16_conv_base(x)

x = layers.Flatten()(x)
x = layers.Dense(256, activation='relu')(x)
    
# The final `Dense` layer with the number of classes.
outputs = layers.Dense(DatasetConfig.NUM_CLASSES, activation='softmax')(x)
    
# The final model.
vgg16_model = keras.Model(inputs, outputs)

print(vgg16_model.summary())
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  tf.__operators__.getitem (S  (None, 224, 224, 3)      0
#  licingOpLambda)
#
#  tf.nn.bias_add (TFOpLambda)  (None, 224, 224, 3)      0
#
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dense (Dense)               (None, 256)               6422784
#
#  dense_1 (Dense)             (None, 29)                7453
#
# =================================================================
# Total params: 21,144,925
# Trainable params: 6,430,237
# Non-trainable params: 14,714,688
# _________________________________________________________________
# None

# %% [markdown]
# ### 4.3 Prepare the Training and Validation Dataset
#
# Since the ASL dataset does not contain separate `train` and `validation` components, we will need to split off a portion of the dataset to reserve for validation. This is accomplished by using `subset='training'` `subset='validation'` in conjunction with `validation_split=0.2`.

# %%
train_dataset = image_dataset_from_directory(directory=DatasetConfig.DATA_ROOT,
                                             batch_size=TrainingConfig.BATCH_SIZE,
                                             shuffle=True,
                                             seed=SEED_VALUE,
                                             label_mode='categorical',
                                             image_size=(DatasetConfig.IMG_WIDTH, DatasetConfig.IMG_HEIGHT),
                                             subset='training',
                                             validation_split=0.2
                                            )

valid_dataset = image_dataset_from_directory(directory=DatasetConfig.DATA_ROOT,
                                             batch_size=TrainingConfig.BATCH_SIZE,
                                             shuffle=True,
                                             seed=SEED_VALUE,
                                             label_mode='categorical',
                                             image_size=(DatasetConfig.IMG_WIDTH, DatasetConfig.IMG_HEIGHT),
                                             subset='validation',
                                             validation_split=0.2
                                            )
# Out:
# Found 4350 files belonging to 29 classes.
# Using 3480 files for training.
# Found 4350 files belonging to 29 classes.
# Using 870 files for validation.

# %% [markdown]
# ### 4.4 Display Sample Images

# %%
class_names = train_dataset.class_names

plt.figure(figsize=(18, 10))

# Assumes dataset batch_size is at least 32.
num_rows = 4
num_cols = 8

# Here we use the take() method to retrieve just the first batch of data from the training portion of the dataset.
for image_batch, labels_batch in train_dataset.take(1): 
    
    # For the batch of images and the associated (one-hot encoded) labels, 
    # plot each of the images in the batch and the associated ground truth labels.
    for idx in range(num_rows*num_cols):
        ax = plt.subplot(num_rows, num_cols, idx + 1)
        plt.imshow(image_batch[idx].numpy().astype("uint8"))
        truth_idx = np.nonzero(labels_batch[idx].numpy())
        plt.title(class_names[truth_idx[0][0]])
        plt.axis("off")

# %% [markdown]
# ### 4.5 Compile and Evaluate the Base Model Prior Final Training
# At this point we can compile and evaluate the model before training the dense classifier.

# %%
vgg16_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=TrainingConfig.LEARNING_RATE),
                    loss=tf.keras.losses.CategoricalCrossentropy(from_logits=False),
                    metrics=['accuracy'],
                   )

# %%
# Save best model based on highest validation_accuracy.
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(filepath=TrainingConfig.CHECKPOINT_DIR,
                                                               save_weights_only=False,
                                                               monitor='val_accuracy',
                                                               mode='max',
                                                               save_best_only=True,
                                                              )

# %% [markdown]
# Checking model accuracy before transfer learning.

# %%
print(f"Model evaluation accuracy: {vgg16_model.evaluate(valid_dataset)[1]*100.:.3f}")
# Out:
# 28/28 [==============================] - 12s 95ms/step - loss: 18.1345 - accuracy: 0.0287
# Model evaluation accuracy: 2.874

# %% [markdown]
# ### 4.6 Train the Model

# %%
# Train the Model.
training_results = vgg16_model.fit(train_dataset,
                                   validation_data=valid_dataset,
                                   epochs=TrainingConfig.EPOCHS,
                                   workers=4,
                                   use_multiprocessing=True, 
                                   callbacks=model_checkpoint_callback,
                                   )
# Out:
# Epoch 1/51
# 109/109 [==============================] - ETA: 0s - loss: 3.4290 - accuracy: 0.4842INFO:tensorflow:Assets written to: ./saved_models_asl/assets
# 109/109 [==============================] - 17s 146ms/step - loss: 3.4290 - accuracy: 0.4842 - val_loss: 1.0147 - val_accuracy: 0.7230
# Epoch 2/51
# 109/109 [==============================] - ETA: 0s - loss: 0.2309 - accuracy: 0.9319INFO:tensorflow:Assets written to: ./saved_models_asl/assets
# 109/109 [==============================] - 15s 139ms/step - loss: 0.2309 - accuracy: 0.9319 - val_loss: 0.5441 - val_accuracy: 0.8540
# Epoch 3/51
# 109/109 [==============================] - ETA: 0s - loss: 0.0503 - accuracy: 0.9862INFO:tensorflow:Assets written to: ./saved_models_asl/assets
# 109/109 [==============================] - 16s 141ms/step - loss: 0.0503 - accuracy: 0.9862 - val_loss: 0.4406 - val_accuracy: 0.8713
# Epoch 4/51
# 109/109 [==============================] - ETA: 0s - loss: 0.0166 - accuracy: 0.9977INFO:tensorflow:Assets written to: ./saved_models_asl/assets
# 109/109 [==============================] - 16s 139ms/step - loss: 0.0166 - accuracy: 0.9977 - val_loss: 0.3686 - val_accuracy: 0.9046
# Epoch 5/51
# 109/109 [==============================] - 12s 111ms/step - loss: 0.0050 - accuracy: 0.9997 - val_loss: 0.3526 - val_accuracy: 0.8977
# Epoch 6/51
# 109/109 [==============================] - ETA: 0s - loss: 0.0024 - accuracy: 1.0000INFO:tensorflow:Assets written to: ./saved_models_asl/assets
# 109/109 [==============================] - 16s 142ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.3395 - val_accuracy: 0.9092
# Epoch 7/51
# 109/109 [==============================] - ETA: 0s - loss: 0.0016 - accuracy: 1.0000INFO:tensorflow:Assets written to: ./saved_models_asl/assets
# 109/109 [==============================] - 15s 139ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.3357 - val_accuracy: 0.9115
# Epoch 8/51
# 109/109 [==============================] - ETA: 0s - loss: 0.0013 - accuracy: 1.0000INFO:tensorflow:Assets written to: ./saved_models_asl/assets
# 109/109 [==============================] - 16s 142ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.3319 - val_accuracy: 0.9149
# Epoch 9/51
# 109/109 [==============================] - 12s 111ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.3287 - val_accuracy: 0.9149
# Epoch 10/51
# 109/109 [==============================] - 13s 112ms/step - loss: 9.5988e-04 - accuracy: 1.0000 - val_loss: 0.3270 - val_accuracy: 0.9149
# Epoch 11/51
# 109/109 [==============================] - 13s 112ms/step - loss: 8.3837e-04 - accuracy: 1.0000 - val_loss: 0.3256 - val_accuracy: 0.9149
# Epoch 12/51
# 109/109 [==============================] - 13s 112ms/step - loss: 7.4708e-04 - accuracy: 1.0000 - val_loss: 0.3244 - val_accuracy: 0.9149
# Epoch 13/51
# 109/109 [==============================] - 12s 111ms/step - loss: 6.6487e-04 - accuracy: 1.0000 - val_loss: 0.3220 - val_accuracy: 0.9138
# Epoch 14/51
# 109/109 [==============================] - 13s 111ms/step - loss: 5.9944e-04 - accuracy: 1.0000 - val_loss: 0.3203 - val_accuracy: 0.9149
# Epoch 15/51
# 109/109 [==============================] - 13s 111ms/step - loss: 5.3899e-04 - accuracy: 1.0000 - val_loss: 0.3185 - val_accuracy: 0.9149
# Epoch 16/51
# 109/109 [==============================] - ETA: 0s - loss: 4.8892e-04 - accuracy: 1.0000INFO:tensorflow:Assets written to: ./saved_models_asl/assets
# 109/109 [==============================] - 16s 141ms/step - loss: 4.8892e-04 - accuracy: 1.0000 - val_loss: 0.3164 - val_accuracy: 0.9172
# Epoch 17/51
# 109/109 [==============================] - 13s 112ms/step - loss: 4.4538e-04 - accuracy: 1.0000 - val_loss: 0.3151 - val_accuracy: 0.9149
# Epoch 18/51
# 109/109 [==============================] - 13s 112ms/step - loss: 4.0336e-04 - accuracy: 1.0000 - val_loss: 0.3120 - val_accuracy: 0.9161
# Epoch 19/51
# 109/109 [==============================] - 13s 112ms/step - loss: 3.6718e-04 - accuracy: 1.0000 - val_loss: 0.3080 - val_accuracy: 0.9172
# Epoch 20/51
# 109/109 [==============================] - ETA: 0s - loss: 3.3564e-04 - accuracy: 1.0000INFO:tensorflow:Assets written to: ./saved_models_asl/assets
# 109/109 [==============================] - 16s 140ms/step - loss: 3.3564e-04 - accuracy: 1.0000 - val_loss: 0.3063 - val_accuracy: 0.9184
# Epoch 21/51
# 109/109 [==============================] - 13s 112ms/step - loss: 3.0683e-04 - accuracy: 1.0000 - val_loss: 0.3056 - val_accuracy: 0.9184
# Epoch 22/51
# 109/109 [==============================] - ETA: 0s - loss: 2.8105e-04 - accuracy: 1.0000INFO:tensorflow:Assets written to: ./saved_models_asl/assets
# 109/109 [==============================] - 16s 143ms/step - loss: 2.8105e-04 - accuracy: 1.0000 - val_loss: 0.3038 - val_accuracy: 0.9195
# Epoch 23/51
# 109/109 [==============================] - 13s 112ms/step - loss: 2.5744e-04 - accuracy: 1.0000 - val_loss: 0.3027 - val_accuracy: 0.9184
# Epoch 24/51
# 109/109 [==============================] - 13s 112ms/step - loss: 2.3689e-04 - accuracy: 1.0000 - val_loss: 0.3019 - val_accuracy: 0.9184
# Epoch 25/51
# 109/109 [==============================] - 13s 112ms/step - loss: 2.1830e-04 - accuracy: 1.0000 - val_loss: 0.3022 - val_accuracy: 0.9184
# Epoch 26/51
# 109/109 [==============================] - 13s 113ms/step - loss: 2.0056e-04 - accuracy: 1.0000 - val_loss: 0.3006 - val_accuracy: 0.9184
# Epoch 27/51
# 109/109 [==============================] - ETA: 0s - loss: 1.8420e-04 - accuracy: 1.0000INFO:tensorflow:Assets written to: ./saved_models_asl/assets
# 109/109 [==============================] - 16s 140ms/step - loss: 1.8420e-04 - accuracy: 1.0000 - val_loss: 0.2996 - val_accuracy: 0.9207
# Epoch 28/51
# 109/109 [==============================] - 13s 112ms/step - loss: 1.6938e-04 - accuracy: 1.0000 - val_loss: 0.2985 - val_accuracy: 0.9207
# Epoch 29/51
# 109/109 [==============================] - 13s 113ms/step - loss: 1.5672e-04 - accuracy: 1.0000 - val_loss: 0.2977 - val_accuracy: 0.9207
# Epoch 30/51
# 109/109 [==============================] - ETA: 0s - loss: 1.4432e-04 - accuracy: 1.0000INFO:tensorflow:Assets written to: ./saved_models_asl/assets
# 109/109 [==============================] - 16s 144ms/step - loss: 1.4432e-04 - accuracy: 1.0000 - val_loss: 0.2958 - val_accuracy: 0.9218
# Epoch 31/51
# 109/109 [==============================] - 13s 113ms/step - loss: 1.3325e-04 - accuracy: 1.0000 - val_loss: 0.2948 - val_accuracy: 0.9218
# Epoch 32/51
# 109/109 [==============================] - 13s 112ms/step - loss: 1.2315e-04 - accuracy: 1.0000 - val_loss: 0.2937 - val_accuracy: 0.9218
# Epoch 33/51
# 109/109 [==============================] - 13s 112ms/step - loss: 1.1372e-04 - accuracy: 1.0000 - val_loss: 0.2940 - val_accuracy: 0.9218
# Epoch 34/51
# 109/109 [==============================] - ETA: 0s - loss: 1.0493e-04 - accuracy: 1.0000INFO:tensorflow:Assets written to: ./saved_models_asl/assets
# 109/109 [==============================] - 16s 142ms/step - loss: 1.0493e-04 - accuracy: 1.0000 - val_loss: 0.2917 - val_accuracy: 0.9230
# Epoch 35/51
# 109/109 [==============================] - 13s 113ms/step - loss: 9.7602e-05 - accuracy: 1.0000 - val_loss: 0.2913 - val_accuracy: 0.9230
# Epoch 36/51
# 109/109 [==============================] - 13s 113ms/step - loss: 9.0609e-05 - accuracy: 1.0000 - val_loss: 0.2909 - val_accuracy: 0.9230
# Epoch 37/51
# 109/109 [==============================] - 13s 112ms/step - loss: 8.4337e-05 - accuracy: 1.0000 - val_loss: 0.2897 - val_accuracy: 0.9230
# Epoch 38/51
# 109/109 [==============================] - 13s 113ms/step - loss: 7.8472e-05 - accuracy: 1.0000 - val_loss: 0.2883 - val_accuracy: 0.9230
# Epoch 39/51
# 109/109 [==============================] - 13s 113ms/step - loss: 7.3270e-05 - accuracy: 1.0000 - val_loss: 0.2883 - val_accuracy: 0.9218
# Epoch 40/51
# 109/109 [==============================] - 13s 114ms/step - loss: 6.8207e-05 - accuracy: 1.0000 - val_loss: 0.2864 - val_accuracy: 0.9230
# Epoch 41/51
# 109/109 [==============================] - 13s 114ms/step - loss: 6.3745e-05 - accuracy: 1.0000 - val_loss: 0.2858 - val_accuracy: 0.9230
# Epoch 42/51
# 109/109 [==============================] - 13s 112ms/step - loss: 5.9672e-05 - accuracy: 1.0000 - val_loss: 0.2849 - val_accuracy: 0.9230
# Epoch 43/51
# 109/109 [==============================] - ETA: 0s - loss: 5.5760e-05 - accuracy: 1.0000INFO:tensorflow:Assets written to: ./saved_models_asl/assets
# 109/109 [==============================] - 16s 143ms/step - loss: 5.5760e-05 - accuracy: 1.0000 - val_loss: 0.2843 - val_accuracy: 0.9241
# Epoch 44/51
# 109/109 [==============================] - 13s 112ms/step - loss: 5.2242e-05 - accuracy: 1.0000 - val_loss: 0.2835 - val_accuracy: 0.9241
# Epoch 45/51
# 109/109 [==============================] - 13s 112ms/step - loss: 4.9031e-05 - accuracy: 1.0000 - val_loss: 0.2831 - val_accuracy: 0.9241
# Epoch 46/51
# 109/109 [==============================] - 13s 112ms/step - loss: 4.5984e-05 - accuracy: 1.0000 - val_loss: 0.2826 - val_accuracy: 0.9241
# Epoch 47/51
# 109/109 [==============================] - 13s 112ms/step - loss: 4.3174e-05 - accuracy: 1.0000 - val_loss: 0.2830 - val_accuracy: 0.9241
# Epoch 48/51
# 109/109 [==============================] - 13s 118ms/step - loss: 4.0612e-05 - accuracy: 1.0000 - val_loss: 0.2816 - val_accuracy: 0.9241
# Epoch 49/51
# 109/109 [==============================] - 13s 113ms/step - loss: 3.8118e-05 - accuracy: 1.0000 - val_loss: 0.2813 - val_accuracy: 0.9241
# Epoch 50/51
# 109/109 [==============================] - 13s 113ms/step - loss: 3.5706e-05 - accuracy: 1.0000 - val_loss: 0.2805 - val_accuracy: 0.9241
# Epoch 51/51
# 109/109 [==============================] - 13s 114ms/step - loss: 3.3461e-05 - accuracy: 1.0000 - val_loss: 0.2803 - val_accuracy: 0.9241

# %% [markdown]
# ### 4.7 Plot the Training Results

# %%
def plot_results(metrics, ylabel=None, ylim=None, metric_name=None, color=None):
    
    fig, ax = plt.subplots(figsize=(15, 4))

    if not (isinstance(metric_name, list) or isinstance(metric_name, tuple)):
        metrics = [metrics,]
        metric_name = [metric_name,]
        
    for idx, metric in enumerate(metrics):    
        ax.plot(metric, color=color[idx])
    
    plt.xlabel("Epoch")
    plt.ylabel(ylabel)
    plt.title(ylabel)
    plt.xlim([0, TrainingConfig.EPOCHS-1])
    plt.ylim(ylim)
    # Tailor x-axis tick marks
    ax.xaxis.set_major_locator(MultipleLocator(5))
    ax.xaxis.set_major_formatter(FormatStrFormatter('%d'))
    ax.xaxis.set_minor_locator(MultipleLocator(1))
    plt.grid(True)
    plt.legend(metric_name)   
    plt.show(block=block_plot)
    plt.close()

# %%
# Retrieve training results.
train_loss = training_results.history["loss"]
train_acc  = training_results.history["accuracy"]
valid_loss = training_results.history["val_loss"]
valid_acc  = training_results.history["val_accuracy"]
    
plot_results([ train_acc, valid_acc ], 
            ylabel="Accuracy",
            ylim = [0.5, 1.0],
            metric_name=["Training Accuracy", "Validation Accuracy"],
            color=["g", "b"])
 
max_loss = 2.0

plot_results([ train_loss, valid_loss ],        
            ylabel="Loss", 
            ylim = [0.0, max_loss],
            metric_name=["Training Loss", "Validation Loss"],
            color=["g", "b"]);

# %% [markdown]
# ## 5 Model Evaluation

# %%
# Load saved model.
# Final evaluation accuracy on the validation set.
model = tf.keras.models.load_model(TrainingConfig.CHECKPOINT_DIR)
print(f"Model evaluation accuracy: {model.evaluate(valid_dataset)[1]*100.:.3f}")
# Out:
# 28/28 [==============================] - 3s 86ms/step - loss: 0.2843 - accuracy: 0.9241
# Model evaluation accuracy: 92.414

# %%
def display_wrong_predictions(dataset, checkpoint_dir=None, checkpoint_version=0):
    
    if not checkpoint_dir:
        checkpoint_dir = os.path.join(os.getcwd(), TrainingConfig.checkpoint_dir, f"version_{checkpoint_version}")
        
    # Load saved model.
    model = tf.keras.models.load_model(checkpoint_dir)
    
    plt.figure(figsize=(20, 15))
    num_rows = 4
    num_cols = 5
    class_names = dataset.class_names
    jdx = 0
    
    # Evaluate all the batches.
    for image_batch, labels_batch in dataset:
        
        # Predictions for the current batch.
        predictions = model.predict(image_batch)
        
        # Loop over all the images in the current batch.
        for idx in range(len(labels_batch)):
            
            pred_idx = tf.argmax(predictions[idx]).numpy()
            truth_idx = np.nonzero(labels_batch[idx].numpy())
            
            # Plot the images with incorrect predictions
            if pred_idx != truth_idx:
                
                jdx += 1
                
                if jdx > num_rows*num_cols:
                    # Break from the loops if the maximum number of images have been plotted
                    break
                
                ax = plt.subplot(num_rows, num_cols, jdx)
                title = str(class_names[truth_idx[0][0]]) + " : " + str(class_names[pred_idx])
                title_obj = plt.title(title)
                plt.setp(title_obj, color='r')
                plt.axis("off")
                plt.imshow(image_batch[idx].numpy().astype("uint8"))
    return

# %%
display_wrong_predictions(valid_dataset, TrainingConfig.CHECKPOINT_DIR)

# %% [markdown]
# ## 6 Conclusion

# %% [markdown]
# In this notebook, we used a different dataset to experiment with **transfer learning**, and we saw that the validation accuracy on the **ASL** dataset wasn't nearly as good as compared to the **Type of Balls** dataset. The reason for this is that the transfer learning was based on the ImageNet dataset, which contains representations of various types of balls, but has no representations for hand signals. Therefore, the convolutional base that was used for transfer learning, in this case, lacks the lower-level features that would be helpful for classifying hand signals. In the next notebook, we are going to revisit this example by training the last few layers of the convolutional base. This extension to transfer learning is called **fine-tuning.**
