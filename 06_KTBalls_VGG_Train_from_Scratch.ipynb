# %% [markdown]
# <h1 style="font-size:30px;">Implementing VGG-16 (Train from Scratch)</h1>
#
# In this notebook, we are going to experiment with a Deep CNN - the <a href="https://arxiv.org/pdf/1409.1556v6.pdf" target="_blank">VGG-16 neural network</a> using TensorFlow. As a convenience, TensorFlow provides a model of the VGG-16 network within its `tf.keras.applications` module, so we can load the model directly without implementing the individual layers in Keras. We will instantiate a model of VGG-16 network architecture and train it from scratch on the **types of balls** dataset. This will be accomplished by instantiating the convolutional base of the network and chaining that together with a new dense classifier that we define.
#
# We will see that training a relatively large model from scratch like VGG-16 can be time-consuming. Moreover, training it on a small dataset may lead to overfitting which limits validation accuracy. In subsequent videos, we will address these limitations by using a technique called **transfer learning**.  We will instaniate the model with pre-trained weights from the ImageNet dataset which will lead to improved model accuracy and robustness.
#
# ## VGG-16 Architecture (ImageNet)
#
# The VGG-16 architecture was originally designed and trained on ImageNet. Networks like VGG-16 consist of a **convolutional base** and a **dense classifier**. The dense classifier in VGG-16 consisted of two fully connected layers (each with 4,096 nodes) plus a final output layer containing 1,000 nodes for the 1,000 classes in ImageNet. Before we attempt to retrain this network for a different dataset we will need to replace the dense classifier.
#
# <img src='https://opencv.org/wp-content/uploads/2022/03/c4_03_cnn_vgg_architecture.png' width=700 align='center'><br/>
#
# ## VGG-16 Modified Architecture with New Dense Layer (Types of Balls)
#
# To repurpose this network architecture for a different dataset, we need to replace the fully connected layers. In this example, we choose to include a single fully connected layer with 256 nodes, followed by an output layer of 10 nodes for the 10 classes in the Type of Balls dataset.
#
# <img src='https://opencv.org/wp-content/uploads/2022/03/c4_03_cnn_vgg_architecture_balls.png'><br/>

# %% [markdown]
# ## Table of Contents
# * [1 System Configuration](#1-System-Configuration)
# * [2 Download and Extract the Dataset](#2-Download-and-Extract-the-Dataset)
# * [3 Dataset and Training Configuration](#3-Dataset-and-Training-Configuration)
# * [4 Modeling VGG-16](#4-Modeling-VGG-16)
# * [5 Model Evaluation](#5-Model-Evaluation)
# * [6 Conclusion](#6-Conclusion)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import random
import numpy as np
import os
import matplotlib.pyplot as plt
import cv2
import zipfile
import requests
import glob as glob

from tensorflow.keras.utils import image_dataset_from_directory

from matplotlib.ticker import (MultipleLocator, FormatStrFormatter)
from dataclasses import dataclass 

block_plot = False
plt.rcParams['figure.figsize'] = (12, 9) 
SEED_VALUE = 42

# %% [markdown]
# ## 1 System Configuration

# %%
def system_config():
    
    # Get list of GPUs.
    gpu_devices = tf.config.list_physical_devices('GPU')
    print(gpu_devices)
    
    if len(gpu_devices) > 0:
        print('Using GPU')
        os.environ["CUDA_VISIBLE_DEVICES"] = '0'
        os.environ['TF_CUDNN_DETERMINISTIC'] = '1' 
        
        # If there are any gpu devices, use first gpu.
        tf.config.experimental.set_visible_devices(gpu_devices[0], 'GPU')
        
        # Grow the memory usage as it is needed by the process.
        tf.config.experimental.set_memory_growth(gpu_devices[0], True)
        
        # Enable using cudNN.
        os.environ['TF_USE_CUDNN'] = "true"
    else:
        print('Using CPU')

system_config()
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Using GPU

# %% [markdown]
# ## 2 Download and Extract the Dataset

# %%
def download_file(url, save_name):
    url = url
    file = requests.get(url)

    open(save_name, 'wb').write(file.content)

# %%
def unzip(zip_file=None):
    try:
        with zipfile.ZipFile(zip_file) as z:
            z.extractall("./")
            print("Extracted all")
    except:
        print("Invalid file")

# %%
download_file( 
    'https://www.dropbox.com/s/6nrjxr2ycnpcy63/dataset_balls.zip?dl=1',
    'dataset_balls.zip'
)
    
unzip(zip_file='dataset_balls.zip')
# Out:
# Extracted all

# %% [markdown]
# ## 3 Dataset and Training Configuration

# %%
@dataclass(frozen=True)
class DatasetConfig:
    NUM_CLASSES: int = 10
    IMG_HEIGHT:  int = 224
    IMG_WIDTH:   int = 224
    CHANNELS:    int = 3
    BATCH_SIZE:  int = 32
    DATA_ROOT_TRAIN: str = './dataset_balls/train'
    DATA_ROOT_VALID: str = './dataset_balls/valid'
        
@dataclass(frozen=True)
class TrainingConfig:
    BATCH_SIZE:     int   = 32
    EPOCHS:         int   = 51
    LEARNING_RATE:  float = 0.0001
    CHECKPOINT_DIR: str   = './saved_models_balls'

# %% [markdown]
# ## 4 Modeling VGG-16
#
# The Keras API provides the following utility to instantiate a VGG-16 model. We will specifically instantiate a model of the convolutional base and create our own classifier layer that will be added to the convolutional base. The model may be loaded with pre-trained weights from ImageNet or initialized to random values. **In this notebook, we will initialize the weights to random values to train the model from scratch**. For more information on the VGG-16 API in Keras refer to the documentation page: <a href="https://www.tensorflow.org/api_docs/python/tf/keras/applications/vgg16/VGG16" target="_blank">Keras VGG-16 API.</a>
# ```python
# tf.keras.applications.vgg16.VGG16(include_top=True,
#                                   weights='imagenet',
#                                   input_tensor=None,
#                                   input_shape=None,
#                                   pooling=None,
#                                   classes=1000,
#                                   classifier_activation='softmax',
#                                  )
# ```

# %% [markdown]
# ### 4.1 VGG-16 Convolutional Base
#
# We begin by creating a model of the VGG-16 convolutional base. We can do this by instantiating the model and setting `include_top = False` which excludes the fully connected layers.

# %%
input_shape = (DatasetConfig.IMG_HEIGHT, DatasetConfig.IMG_WIDTH, DatasetConfig.CHANNELS)

print('Loading model with random initial weights...')
vgg16_conv_base = tf.keras.applications.vgg16.VGG16(input_shape=input_shape,
                                                    include_top=False, # We will supply our own top.
                                                    weights=None,
                                                   )
# Explicity set the `trainable` attribute of the model (this is the default).
vgg16_conv_base.trainable = True
print('All weights trainable, fine tuning...')
# Out:
# Loading model with random initial weights...
# All weights trainable, fine tuning...

# %%
print(vgg16_conv_base.summary())
# Out:
# Model: "vgg16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
# =================================================================
# Total params: 14,714,688
# Trainable params: 14,714,688
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ### 4.2 Add the Classification Layer
# Since we intend to train and use the model to classify balls from the Types of Balls dataset (which has only 10 classes), we will need to add our own classification layer.

# %%
inputs = tf.keras.Input(shape=input_shape)

x = tf.keras.applications.vgg16.preprocess_input(inputs)
    
x = vgg16_conv_base(x)

x = layers.Flatten()(x)
x = layers.Dense(256, activation='relu')(x)
    
# The final `Dense` layer with the number of classes.
outputs = layers.Dense(DatasetConfig.NUM_CLASSES, activation='softmax')(x)
    
# The final model.
vgg16_model = keras.Model(inputs, outputs)

print(vgg16_model.summary())
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  tf.__operators__.getitem (S  (None, 224, 224, 3)      0
#  licingOpLambda)
#
#  tf.nn.bias_add (TFOpLambda)  (None, 224, 224, 3)      0
#
#  vgg16 (Functional)          (None, 7, 7, 512)         14714688
#
#  flatten (Flatten)           (None, 25088)             0
#
#  dense (Dense)               (None, 256)               6422784
#
#  dense_1 (Dense)             (None, 10)                2570
#
# =================================================================
# Total params: 21,140,042
# Trainable params: 21,140,042
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# ### 4.3 Prepare the Training and Validation Dataset

# %%
train_dataset = image_dataset_from_directory(directory=DatasetConfig.DATA_ROOT_TRAIN,
                                             batch_size=TrainingConfig.BATCH_SIZE,
                                             seed=SEED_VALUE,
                                             label_mode='categorical',
                                             image_size=(DatasetConfig.IMG_WIDTH, DatasetConfig.IMG_HEIGHT),
                                             )

valid_dataset = image_dataset_from_directory(directory=DatasetConfig.DATA_ROOT_VALID,
                                             batch_size=TrainingConfig.BATCH_SIZE,
                                             seed=SEED_VALUE,
                                             label_mode='categorical',
                                             image_size=(DatasetConfig.IMG_WIDTH, DatasetConfig.IMG_HEIGHT),
                                             )
# Out:
# Found 1125 files belonging to 10 classes.
# Found 200 files belonging to 10 classes.

# %% [markdown]
# ### 4.4 Display Sample Images

# %%
class_names = train_dataset.class_names

plt.figure(figsize=(18, 10))

# Assumes dataset batch_size is at least 32.
num_rows = 4
num_cols = 8

# Here we use the take() method to retrieve just the first batch of data from the training portion of the dataset.
for image_batch, labels_batch in train_dataset.take(1): 
    
    # For the batch of images and the associated (one-hot encoded) labels, 
    # plot each of the images in the batch and the associated ground truth labels.
    for idx in range(num_rows*num_cols):
        ax = plt.subplot(num_rows, num_cols, idx + 1)
        plt.imshow(image_batch[idx].numpy().astype("uint8"))
        truth_idx = np.nonzero(labels_batch[idx].numpy())
        plt.title(class_names[truth_idx[0][0]])
        plt.axis("off")

# %% [markdown]
# ### 4.5 Compile and Train the Model

# %%
vgg16_model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=TrainingConfig.LEARNING_RATE),
                    loss=tf.keras.losses.CategoricalCrossentropy(from_logits=False),
                    metrics=['accuracy'],
                   )

# %%
# Save best model based on highest validation_accuracy.
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(filepath=TrainingConfig.CHECKPOINT_DIR,
                                                               save_weights_only=False,
                                                               monitor='val_accuracy',
                                                               mode='max',
                                                               save_best_only=True,
                                                              )

# %%
# Train the Model.
training_results = vgg16_model.fit(train_dataset,
                                   validation_data=valid_dataset,
                                   epochs=TrainingConfig.EPOCHS,
                                   workers=4,
                                   use_multiprocessing=True, 
                                   callbacks=model_checkpoint_callback,
                                  )
# Out:
# Epoch 1/51
# 36/36 [==============================] - ETA: 0s - loss: 2.2068 - accuracy: 0.2018INFO:tensorflow:Assets written to: ./saved_models_balls/assets
# 36/36 [==============================] - 26s 371ms/step - loss: 2.2068 - accuracy: 0.2018 - val_loss: 2.1157 - val_accuracy: 0.1800
# Epoch 2/51
# 36/36 [==============================] - ETA: 0s - loss: 1.7701 - accuracy: 0.3778INFO:tensorflow:Assets written to: ./saved_models_balls/assets
# 36/36 [==============================] - 12s 331ms/step - loss: 1.7701 - accuracy: 0.3778 - val_loss: 1.7002 - val_accuracy: 0.4400
# Epoch 3/51
# 36/36 [==============================] - 9s 250ms/step - loss: 1.4507 - accuracy: 0.5031 - val_loss: 1.5790 - val_accuracy: 0.4250
# Epoch 4/51
# 36/36 [==============================] - ETA: 0s - loss: 1.2561 - accuracy: 0.5573INFO:tensorflow:Assets written to: ./saved_models_balls/assets
# 36/36 [==============================] - 12s 343ms/step - loss: 1.2561 - accuracy: 0.5573 - val_loss: 1.5509 - val_accuracy: 0.5350
# Epoch 5/51
# 36/36 [==============================] - ETA: 0s - loss: 1.0190 - accuracy: 0.6578INFO:tensorflow:Assets written to: ./saved_models_balls/assets
# 36/36 [==============================] - 12s 334ms/step - loss: 1.0190 - accuracy: 0.6578 - val_loss: 1.1350 - val_accuracy: 0.6350
# Epoch 6/51
# 36/36 [==============================] - 9s 250ms/step - loss: 0.8494 - accuracy: 0.7084 - val_loss: 1.1149 - val_accuracy: 0.6300
# Epoch 7/51
# 36/36 [==============================] - 9s 250ms/step - loss: 0.7277 - accuracy: 0.7431 - val_loss: 1.8396 - val_accuracy: 0.5300
# Epoch 8/51
# 36/36 [==============================] - ETA: 0s - loss: 0.7539 - accuracy: 0.7324INFO:tensorflow:Assets written to: ./saved_models_balls/assets
# 36/36 [==============================] - 12s 341ms/step - loss: 0.7539 - accuracy: 0.7324 - val_loss: 1.1107 - val_accuracy: 0.6500
# Epoch 9/51
# 36/36 [==============================] - ETA: 0s - loss: 0.4617 - accuracy: 0.8356INFO:tensorflow:Assets written to: ./saved_models_balls/assets
# 36/36 [==============================] - 12s 335ms/step - loss: 0.4617 - accuracy: 0.8356 - val_loss: 0.9997 - val_accuracy: 0.6850
# Epoch 10/51
# 36/36 [==============================] - 9s 250ms/step - loss: 0.3625 - accuracy: 0.8747 - val_loss: 1.7090 - val_accuracy: 0.6800
# Epoch 11/51
# 36/36 [==============================] - 9s 251ms/step - loss: 0.3074 - accuracy: 0.8916 - val_loss: 1.7011 - val_accuracy: 0.6300
# Epoch 12/51
# 36/36 [==============================] - 9s 251ms/step - loss: 0.2451 - accuracy: 0.9324 - val_loss: 2.6121 - val_accuracy: 0.5800
# Epoch 13/51
# 36/36 [==============================] - 9s 250ms/step - loss: 0.3209 - accuracy: 0.9049 - val_loss: 1.9526 - val_accuracy: 0.5900
# Epoch 14/51
# 36/36 [==============================] - 9s 250ms/step - loss: 0.2381 - accuracy: 0.9200 - val_loss: 1.6287 - val_accuracy: 0.6850
# Epoch 15/51
# 36/36 [==============================] - 9s 250ms/step - loss: 0.1722 - accuracy: 0.9431 - val_loss: 1.6781 - val_accuracy: 0.6700
# Epoch 16/51
# 36/36 [==============================] - 9s 250ms/step - loss: 0.1498 - accuracy: 0.9529 - val_loss: 1.6278 - val_accuracy: 0.6850
# Epoch 17/51
# 36/36 [==============================] - ETA: 0s - loss: 0.1746 - accuracy: 0.9493INFO:tensorflow:Assets written to: ./saved_models_balls/assets
# 36/36 [==============================] - 12s 342ms/step - loss: 0.1746 - accuracy: 0.9493 - val_loss: 1.6300 - val_accuracy: 0.7050
# Epoch 18/51
# 36/36 [==============================] - ETA: 0s - loss: 0.0890 - accuracy: 0.9707INFO:tensorflow:Assets written to: ./saved_models_balls/assets
# 36/36 [==============================] - 12s 332ms/step - loss: 0.0890 - accuracy: 0.9707 - val_loss: 1.7878 - val_accuracy: 0.7200
# Epoch 19/51
# 36/36 [==============================] - 9s 251ms/step - loss: 0.0839 - accuracy: 0.9796 - val_loss: 1.6554 - val_accuracy: 0.7050
# Epoch 20/51
# 36/36 [==============================] - 9s 250ms/step - loss: 0.0515 - accuracy: 0.9858 - val_loss: 1.9747 - val_accuracy: 0.7100
# Epoch 21/51
# 36/36 [==============================] - 9s 250ms/step - loss: 0.0797 - accuracy: 0.9787 - val_loss: 1.7800 - val_accuracy: 0.6850
# Epoch 22/51
# 36/36 [==============================] - 9s 250ms/step - loss: 0.0814 - accuracy: 0.9751 - val_loss: 1.2266 - val_accuracy: 0.7200
# Epoch 23/51
# 36/36 [==============================] - 9s 250ms/step - loss: 0.0650 - accuracy: 0.9778 - val_loss: 1.8427 - val_accuracy: 0.7200
# Epoch 24/51
# 36/36 [==============================] - 9s 250ms/step - loss: 0.0748 - accuracy: 0.9804 - val_loss: 1.7231 - val_accuracy: 0.6850
# Epoch 25/51
# 36/36 [==============================] - 9s 250ms/step - loss: 0.2975 - accuracy: 0.9120 - val_loss: 1.7928 - val_accuracy: 0.6600
# Epoch 26/51
# 36/36 [==============================] - 9s 251ms/step - loss: 0.0857 - accuracy: 0.9742 - val_loss: 1.7997 - val_accuracy: 0.7050
# Epoch 27/51
# 36/36 [==============================] - 9s 250ms/step - loss: 0.0400 - accuracy: 0.9876 - val_loss: 1.7003 - val_accuracy: 0.7050
# Epoch 28/51
# 36/36 [==============================] - 9s 250ms/step - loss: 0.0345 - accuracy: 0.9858 - val_loss: 1.8495 - val_accuracy: 0.7000
# Epoch 29/51
# 36/36 [==============================] - ETA: 0s - loss: 0.0304 - accuracy: 0.9884INFO:tensorflow:Assets written to: ./saved_models_balls/assets
# 36/36 [==============================] - 12s 342ms/step - loss: 0.0304 - accuracy: 0.9884 - val_loss: 1.5359 - val_accuracy: 0.7350
# Epoch 30/51
# 36/36 [==============================] - 9s 250ms/step - loss: 0.0508 - accuracy: 0.9804 - val_loss: 2.1937 - val_accuracy: 0.6850
# Epoch 31/51
# 36/36 [==============================] - 9s 250ms/step - loss: 0.0145 - accuracy: 0.9947 - val_loss: 1.5793 - val_accuracy: 0.7350
# Epoch 32/51
# 36/36 [==============================] - ETA: 0s - loss: 0.0231 - accuracy: 0.9964INFO:tensorflow:Assets written to: ./saved_models_balls/assets
# 36/36 [==============================] - 12s 332ms/step - loss: 0.0231 - accuracy: 0.9964 - val_loss: 1.3837 - val_accuracy: 0.7600
# Epoch 33/51
# 36/36 [==============================] - 9s 250ms/step - loss: 0.0631 - accuracy: 0.9822 - val_loss: 1.7722 - val_accuracy: 0.6750
# Epoch 34/51
# 36/36 [==============================] - 9s 250ms/step - loss: 0.0198 - accuracy: 0.9947 - val_loss: 2.1571 - val_accuracy: 0.7250
# Epoch 35/51
# 36/36 [==============================] - 9s 250ms/step - loss: 0.0382 - accuracy: 0.9920 - val_loss: 1.3133 - val_accuracy: 0.7350
# Epoch 36/51
# 36/36 [==============================] - 9s 250ms/step - loss: 0.0060 - accuracy: 0.9982 - val_loss: 1.5584 - val_accuracy: 0.7200
# Epoch 37/51
# 36/36 [==============================] - 9s 250ms/step - loss: 2.3168e-04 - accuracy: 1.0000 - val_loss: 1.6729 - val_accuracy: 0.7300
# Epoch 38/51
# 36/36 [==============================] - 9s 250ms/step - loss: 1.2540e-04 - accuracy: 1.0000 - val_loss: 1.7086 - val_accuracy: 0.7450
# Epoch 39/51
# 36/36 [==============================] - 9s 250ms/step - loss: 9.5784e-05 - accuracy: 1.0000 - val_loss: 1.7433 - val_accuracy: 0.7400
# Epoch 40/51
# 36/36 [==============================] - 9s 250ms/step - loss: 7.7571e-05 - accuracy: 1.0000 - val_loss: 1.7708 - val_accuracy: 0.7400
# Epoch 41/51
# 36/36 [==============================] - 9s 250ms/step - loss: 6.5162e-05 - accuracy: 1.0000 - val_loss: 1.8058 - val_accuracy: 0.7400
# Epoch 42/51
# 36/36 [==============================] - 9s 249ms/step - loss: 5.5626e-05 - accuracy: 1.0000 - val_loss: 1.8245 - val_accuracy: 0.7450
# Epoch 43/51
# 36/36 [==============================] - 9s 250ms/step - loss: 4.8425e-05 - accuracy: 1.0000 - val_loss: 1.8429 - val_accuracy: 0.7450
# Epoch 44/51
# 36/36 [==============================] - 9s 250ms/step - loss: 4.2792e-05 - accuracy: 1.0000 - val_loss: 1.8594 - val_accuracy: 0.7450
# Epoch 45/51
# 36/36 [==============================] - 9s 250ms/step - loss: 3.8566e-05 - accuracy: 1.0000 - val_loss: 1.8742 - val_accuracy: 0.7450
# Epoch 46/51
# 36/36 [==============================] - 9s 249ms/step - loss: 3.4965e-05 - accuracy: 1.0000 - val_loss: 1.8891 - val_accuracy: 0.7450
# Epoch 47/51
# 36/36 [==============================] - 9s 250ms/step - loss: 3.2004e-05 - accuracy: 1.0000 - val_loss: 1.9020 - val_accuracy: 0.7450
# Epoch 48/51
# 36/36 [==============================] - 9s 249ms/step - loss: 2.9468e-05 - accuracy: 1.0000 - val_loss: 1.9146 - val_accuracy: 0.7450
# Epoch 49/51
# 36/36 [==============================] - 9s 250ms/step - loss: 2.7166e-05 - accuracy: 1.0000 - val_loss: 1.9257 - val_accuracy: 0.7450
# Epoch 50/51
# 36/36 [==============================] - 9s 250ms/step - loss: 2.5215e-05 - accuracy: 1.0000 - val_loss: 1.9389 - val_accuracy: 0.7450
# Epoch 51/51
# 36/36 [==============================] - 9s 250ms/step - loss: 2.3394e-05 - accuracy: 1.0000 - val_loss: 1.9510 - val_accuracy: 0.7450

# %% [markdown]
# ## 4.6 Plot the Training Results

# %%
def plot_results(metrics, ylabel=None, ylim=None, metric_name=None, color=None):
    
    fig, ax = plt.subplots(figsize=(15, 4))

    if not (isinstance(metric_name, list) or isinstance(metric_name, tuple)):
        metrics = [metrics,]
        metric_name = [metric_name,]
        
    for idx, metric in enumerate(metrics):    
        ax.plot(metric, color=color[idx])
    
    plt.xlabel("Epoch")
    plt.ylabel(ylabel)
    plt.title(ylabel)
    plt.xlim([0, TrainingConfig.EPOCHS-1])
    plt.ylim(ylim)
    # Tailor x-axis tick marks
    ax.xaxis.set_major_locator(MultipleLocator(5))
    ax.xaxis.set_major_formatter(FormatStrFormatter('%d'))
    ax.xaxis.set_minor_locator(MultipleLocator(1))
    plt.grid(True)
    plt.legend(metric_name)   
    plt.show(block=block_plot)
    plt.close()

# %%
# Retrieve training results.
train_loss = training_results.history["loss"]
train_acc  = training_results.history["accuracy"]
valid_loss = training_results.history["val_loss"]
valid_acc  = training_results.history["val_accuracy"]
    
plot_results([ train_acc, valid_acc ], 
            ylabel="Accuracy",
            ylim = [0.0, 1.0],
            metric_name=["Training Accuracy", "Validation Accuracy"],
            color=["g", "b"])
 
max_loss = max(max(train_loss), max(valid_loss))

plot_results([ train_loss, valid_loss ],        
            ylabel="Loss", 
            ylim = [0.0, max_loss],
            metric_name=["Training Loss", "Validation Loss"],
            color=["g", "b"]);

# %% [markdown]
# ## 5 Model Evaluation

# %%
# Load saved model.
# Final evaluation accuracy on the validation set.
model = tf.keras.models.load_model(TrainingConfig.CHECKPOINT_DIR)
print(f"Model evaluation accuracy: {model.evaluate(valid_dataset)[1]*100.:.3f}")
# Out:
# 7/7 [==============================] - 1s 77ms/step - loss: 1.3837 - accuracy: 0.7600
# Model evaluation accuracy: 76.000

# %%
def display_wrong_predictions(dataset, checkpoint_dir=None, checkpoint_version=0):
    
    if not checkpoint_dir:
        checkpoint_dir = os.path.join(os.getcwd(), TrainingConfig.checkpoint_dir, f"version_{checkpoint_version}")
        
    # Load saved model.
    model = keras.models.load_model(checkpoint_dir)
    
    plt.figure(figsize=(20, 15))
    num_rows = 4
    num_cols = 5
    class_names = dataset.class_names
    jdx = 0
    
    # Evaluate all the batches.
    for image_batch, labels_batch in dataset:
        
        # Predictions for the current batch.
        predictions = model.predict(image_batch)
        
        # Loop over all the images in the current batch.
        for idx in range(len(labels_batch)):
            
            pred_idx = tf.argmax(predictions[idx]).numpy()
            truth_idx = np.nonzero(labels_batch[idx].numpy())
            
            # Plot the images with incorrect predictions
            if pred_idx != truth_idx:
                
                jdx += 1
                
                if jdx > num_rows*num_cols:
                    # Break from the loops if the maximum number of images have been plotted
                    break
                
                ax = plt.subplot(num_rows, num_cols, jdx)
                title = str(class_names[truth_idx[0][0]]) + " : " + str(class_names[pred_idx])
                title_obj = plt.title(title)
                plt.setp(title_obj, color='r')
                plt.axis("off")
                plt.imshow(image_batch[idx].numpy().astype("uint8"))
    return

# %%
display_wrong_predictions(valid_dataset, TrainingConfig.CHECKPOINT_DIR)

# %% [markdown]
# ## 5 Conclusion

# %% [markdown]
# In this notebook, we demonstrated how to load the VGG-16 model from the Keras applications module and train the model from scratch. We showed that training the model from scratch takes time and that over-fitting becomes a problem that limits the validation accuracy of the model.
